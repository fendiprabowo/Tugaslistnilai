# %%
print("TUGAS 02: LIST NILAI")
print("Fendi Prabowo - C")
print () 

import random

# GENERATE RANDOM
nilaiTugas = []
for i in range(250):
    nilaiTugas.append(random.randrange(1,100,1))

print("Nilai Tugas")
print(nilaiTugas)

# ganjil
print ()
print ("Nilai Ganjil")
nilaiGanjil = []
for n in nilaiTugas:
    if n % 2 == 1: 
        nilaiGanjil.append(n)
print (nilaiGanjil)
print ()
    
# nilai > 70
nilai70 = []
for n in nilaiTugas:
    if n > 70:
        nilai70.append(n)
print("Jumlah nilai yang lebih besar dari 70 adalah sebanyak",len(nilai70))        
print ()

# standar deviasi
total = 0
for n in nilaiTugas:
    total = total + n 
average = total / len(nilaiTugas)

jumlah = 0
for n in nilaiTugas:
    a = (n - average)**2
    jumlah = jumlah + a
stdev = ( jumlah/(len(nilaiTugas)-1))**0.5

print("Standar Deviasi =", stdev)
print ()

# maksimum
maksimum = 0
for n in nilaiTugas:
    if (n>maksimum):
        maksimum = n
print("Nilai maksimum dari list nilai ini adalah",maksimum)

# minimum
minimum = 0
for n in nilaiTugas:
    if (n<minimum):
        minimum = n
print("Nilai minimum dari list nilai ini adalah",minimum)
print ()

# modus
nilaimaks=0
modus={}
for i in nilaiTugas:
    count= nilaiTugas.count(i)
    modus.update({i:count})

for key in modus:
    if modus[key]>nilaimaks:
        nilaimaks=modus[key]

for key in modus:
    if modus[key]==nilaimaks:
         print("Nilai modus dari list nilai ini adalah", key)
# Out:
# TUGAS 02: LIST NILAI
# Fendi Prabowo - C
#
# Nilai Tugas
# [68, 33, 7, 29, 25, 60, 42, 8, 23, 58, 62, 62, 82, 77, 91, 80, 48, 55, 52, 87, 55, 5, 56, 53, 5, 12, 58, 5, 20, 7, 67, 80, 68, 28, 65, 34, 65, 75, 82, 41, 33, 11, 98, 22, 7, 77, 47, 1, 94, 77, 13, 82, 86, 54, 43, 24, 1, 28, 32, 45, 86, 23, 15, 90, 61, 19, 3, 74, 2, 67, 31, 51, 22, 99, 62, 33, 31, 90, 57, 76, 43, 33, 66, 50, 45, 10, 70, 64, 10, 51, 88, 20, 41, 38, 28, 19, 59, 40, 98, 12, 95, 30, 75, 24, 24, 71, 97, 44, 87, 60, 54, 9, 70, 65, 40, 61, 63, 49, 51, 45, 27, 40, 87, 12, 71, 31, 85, 51, 73, 40, 1, 69, 82, 18, 14, 20, 3, 4, 2, 88, 70, 87, 91, 53, 49, 66, 70, 97, 97, 87, 3, 71, 58, 77, 55, 45, 96, 12, 4, 65, 78, 40, 85, 15, 93, 95, 51, 14, 18, 61, 33, 49, 31, 41, 46, 55, 49, 76, 74, 12, 23, 4, 2, 26, 51, 80, 98, 46, 90, 16, 76, 61, 89, 84, 18, 65, 64, 5, 73, 20, 69, 43, 63, 46, 54, 19, 65, 68, 89, 78, 63, 32, 34, 83, 39, 16, 39, 84, 50, 69, 65, 41, 57, 66, 83, 92, 27, 28, 96, 72, 17, 67, 70, 25, 93, 9, 58, 27, 40, 44, 29, 61, 24, 4, 22, 32, 11, 82, 13, 82]
#
# Nilai Ganjil
# [33, 7, 29, 25, 23, 77, 91, 55, 87, 55, 5, 53, 5, 5, 7, 67, 65, 65, 75, 41, 33, 11, 7, 77, 47, 1, 77, 13, 43, 1, 45, 23, 15, 61, 19, 3, 67, 31, 51, 99, 33, 31, 57, 43, 33, 45, 51, 41, 19, 59, 95, 75, 71, 97, 87, 9, 65, 61, 63, 49, 51, 45, 27, 87, 71, 31, 85, 51, 73, 1, 69, 3, 87, 91, 53, 49, 97, 97, 87, 3, 71, 77, 55, 45, 65, 85, 15, 93, 95, 51, 61, 33, 49, 31, 41, 55, 49, 23, 51, 61, 89, 65, 5, 73, 69, 43, 63, 19, 65, 89, 63, 83, 39, 39, 69, 65, 41, 57, 83, 27, 17, 67, 25, 93, 9, 27, 29, 61, 11, 13]
#
# Jumlah nilai yang lebih besar dari 70 adalah sebanyak 65
#
# Standar Deviasi = 27.978219870974538
#
# Nilai maksimum dari list nilai ini adalah 99
# Nilai minimum dari list nilai ini adalah 0
#
# Nilai modus dari list nilai ini adalah 65
